# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN               BELÉM            PA
# 2                 NaN                  NaN      RIO DE JANEIRO            RJ
# 3      -13.1066666667       -55.9930555556  LUCAS DO RIO VERDE            MT
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# ...

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              39789               39789               39789
# 40              39158               39158               39158
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               39789               39789                INCIDENTE
# 40               39158               39158                INCIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 NaN                  NaN  SÃO PEDRO DO SUL            RS
# 40                 ***                  ***             BELÉM            PA
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 10  ...     2010-01-10        21:30:00                            ***
# 40  ...     2010-01-28        16:00:00                            SIM
#
#    investigacao_status divulgacao_relatorio_numero  \
# 10                 NaN                         NaN
# ...

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 40211                           40211               40211               40211
# 40349                           40349               40349               40349
# 40351                           40351               40351               40351
# 39527                           39527               39527               39527
# 40324                           40324               40324               40324
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                   ocorrencia_latitude ocorrencia_longitude  \
# ...

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia1                              40324
# codigo_ocorrencia2                              40324
# codigo_ocorrencia3                              40324
# codigo_ocorrencia4                              40324
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                             PELOTAS
# ocorrencia_uf                                      RS
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBPK
# ocorrencia_dia                    2010-01-05 00:00:00
# ocorrencia_hora                              19:25:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       NaN
# divulgacao_relatorio_publicado                    NÃO
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
# 1               40349               40349               40349
# 2               40351               40351               40351
# 3               39527               39527               39527
# 4               40324               40324               40324
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
# 1               40349                INCIDENTE                 NaN
# 2               40351                INCIDENTE                 NaN
# 3               39527                 ACIDENTE      -13.1066666667
# 4               40324                INCIDENTE                 NaN
#
#   ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***      RIO DE JANEIRO            RJ          BRASIL  ...
# ...

# %%
df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               40211               40211               40211
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               40211                INCIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  ***    RIO DE JANEIRO            RJ          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2010-01-03        12:00:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0          FINALIZADA                         ***
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     NÃO
#
# [1 rows x 21 columns]

# %%
df['ocorrenia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  40211               40211               40211
# 1                  40349               40349               40349
# 2                  40351               40351               40351
# 3                  39527               39527               39527
# 4                  40324               40324               40324
# ...                  ...                 ...                 ...
# 5747               79804               79804               79804
# 5748               79757               79757               79757
# 5749               79802               79802               79802
# 5750               79756               79756               79756
# 5751               79844               79844               79844
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  40211                INCIDENTE                 ***
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 11                 40069               40069               40069
# 16                 39809               39809               39809
# 18                 39828               39828               39828
# 26                 39847               39847               39847
# 27                 39768               39768               39768
# ...                  ...                 ...                 ...
# 5704               79739               79739               79739
# 5705               79705               79705               79705
# 5715               79718               79718               79718
# 5742               79800               79800               79800
# 5747               79804               79804               79804
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 11                 40069                    GRAVE      -23.5069444444
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %% [raw]
# Limpeza de dados não informados em:
# ocorrencia_uf
# **
# ocorrencia_aerodromo
# ###!
# ####
# ****
# *****
# ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              40211               40211               40211
# 1              40349               40349               40349
# 2              40351               40351               40351
# 3              39527               39527               39527
# 4              40324               40324               40324
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               40211               40211                INCIDENTE
# 1               40349               40349                INCIDENTE
# 2               40351               40351                INCIDENTE
# 3               39527               39527                 ACIDENTE
# 4               40324               40324                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf  \
# 0                 ***                  ***      RIO DE JANEIRO            RJ
# ...

# %%
df.replace(['**', '***', '###!', '****', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %% [raw]
# Mostrando abaixo quantos dados não informados há no dataframe com função isna ou isnull:

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia                    0
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2295
# ocorrencia_longitude              2297
# ocorrencia_cidade                    0
# ocorrencia_uf                        1
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2336
# ocorrencia_dia                       0
# ocorrencia_hora                      1
# investigacao_aeronave_liberada    2482
# investigacao_status                340
# divulgacao_relatorio_numero       3800
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4258
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# dtype: int64

# %% [raw]
# Para inserir dados, caso solicitado, onde não ha dados não-informado use: df.fillna(dado, inplace=True)
# Caso necessário reverter use: df.replace([dado], pd.NA, inplace=True)

# %% [raw]
# Para inserir em uma coluna específica use: df.fillna(value={'coluna':dado}, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# 2                 40351               40351               40351
# 3                 39527               39527               39527
# 4                 40324               40324               40324
# ...                 ...                 ...                 ...
# 5747              79804               79804               79804
# 5748              79757               79757               79757
# 5749              79802               79802               79802
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# ...

# %% [raw]
# Excluir as colunas:
# codigo_ocorrencia1 , codigo_ocorrencia3	, codigo_ocorrencia4 , ocorrencia_latitude ,
# ocorrencia_longitude , investigacao_aeronave_liberada ,	investigacao_status	, divulgacao_relatorio_numero divulgacao_relatorio_publicado , divulgacao_dia_publicacao , total_aeronaves_envolvidas ,ocorrencia_saida_pista, ocorrencia_pais

# %%
df.drop(['ocorrencia_pais'], axis=1, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %% [raw]
# Para remover valores não informados(remove as linhas tambem) usando como parametro o nome da coluna:
# df.drop(subset=['codigo_ocorrencia3'])
#
# Para remover linhas de valores duplicados:
# df.drop_duplicates(inplace=True)
